# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

data = pd.read_csv('covidata.csv')
data.replace([97, 98, 99, '9999-99-99'], np.nan, inplace=True)
data.fillna(data.mode().iloc[0], inplace=True)
data.drop(['USMER', 'MEDICAL_UNIT', 'DATE_DIED'], axis=1, inplace=True)
data = pd.get_dummies(data, columns=['SEX', 'PATIENT_TYPE'], drop_first=True)

data = pd.read_csv('covidata.csv')
data.replace([97, 98, 99, '9999-99-99'], np.nan, inplace=True)
data.fillna(data.mode().iloc[0], inplace=True)
data.drop(['USMER', 'MEDICAL_UNIT', 'DATE_DIED'], axis=1, inplace=True)
data = pd.get_dummies(data, columns=['SEX', 'PATIENT_TYPE'], drop_first=True)

#variables
X = data.drop(['CLASIFFICATION_FINAL'], axis=1)
y = data['CLASIFFICATION_FINAL'] - data['CLASIFFICATION_FINAL'].min()
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
y_train = tf.keras.utils.to_categorical(y_train, num_classes=y.nunique())
y_test = tf.keras.utils.to_categorical(y_test, num_classes=y.nunique())

#tamaño para pruebas
X_train_small = X_train[:5000]
y_train_small = y_train[:5000]

#modelo LSTM
model = Sequential([
    Input(shape=(X_train.shape[1], 1)),
    LSTM(16, return_sequences=True),
    BatchNormalization(),
    Dropout(0.2),
    LSTM(8),
    BatchNormalization(),
    Dropout(0.2),
    Dense(y.nunique(), activation='softmax')
])

#compilacion y entrenamiento con early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
model.compile(optimizer=Adam(learning_rate=0.0005), loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train_small, y_train_small, epochs=30, batch_size=128, validation_data=(X_test, y_test), callbacks=[early_stop], verbose=1)

loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'pérdida de prueba: {loss:.4f}')
print(f'precisión de la prueba: {accuracy:.4f}')

import matplotlib.pyplot as plt

# Entrenamiento del modelo (guardando historial)
history = model.fit(
    X_train_small, y_train_small,
    epochs=30,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[early_stop],
    verbose=1
)

#perdida
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='entrenamiento')
plt.plot(history.history['val_loss'], label='validación')
plt.title('pérdida por época')
plt.xlabel('época')
plt.ylabel('pérdida')
plt.legend()

#precision
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='entrenamiento')
plt.plot(history.history['val_accuracy'], label='validación')
plt.title('precisión por época')
plt.xlabel('epoca')
plt.ylabel('precisión')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - accuracy: 0.1642 - loss: 2.3332 - val_accuracy: 0.1136 - val_loss: 1.9856
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 0.2272 - loss: 2.1426 - val_accuracy: 0.3635 - val_loss: 1.8758
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - accuracy: 0.2708 - loss: 2.0152 - val_accuracy: 0.3635 - val_loss: 1.8020
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 0.2984 - loss: 1.9619 - val_accuracy: 0.3635 - val_loss: 1.6872
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 167ms/step - accuracy: 0.3361 - loss: 1.8749 - val_accuracy: 0.3635 - val_loss: 1.6380
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step - accuracy: 0.3460 - loss: 1.8059 - val_accuracy: 0.3635 - val_loss: 1.5577
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 0.3665 - loss: 1.7791 - val_accuracy: 0.3635 - val_loss: 1.5791
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 171ms/step - accuracy: 0.4030 - loss: 1.7107 - val_accuracy: 0.3635 - val_loss: 1.5145
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 0.4201 - loss: 1.6602 - val_accuracy: 0.3635 - val_loss: 1.5175
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 166ms/step - accuracy: 0.4208 - loss: 1.6280 - val_accuracy: 0.3635 - val_loss: 1.7072
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - accuracy: 0.4464 - loss: 1.5806 - val_accuracy: 0.3635 - val_loss: 1.5039
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 0.4814 - loss: 1.5251 - val_accuracy: 0.3897 - val_loss: 1.4368
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 169ms/step - accuracy: 0.4575 - loss: 1.5092 - val_accuracy: 0.4338 - val_loss: 1.4513
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 170ms/step - accuracy: 0.4692 - loss: 1.4599 - val_accuracy: 0.3752 - val_loss: 1.4631
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 196ms/step - accuracy: 0.4651 - loss: 1.4415 - val_accuracy: 0.4886 - val_loss: 1.4330
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - accuracy: 0.4841 - loss: 1.3946 - val_accuracy: 0.4802 - val_loss: 1.3500
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - accuracy: 0.4708 - loss: 1.3827 - val_accuracy: 0.5079 - val_loss: 1.2721
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - accuracy: 0.4828 - loss: 1.3549 - val_accuracy: 0.5049 - val_loss: 1.3370
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - accuracy: 0.4878 - loss: 1.3250 - val_accuracy: 0.4846 - val_loss: 1.3438
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - accuracy: 0.4826 - loss: 1.3132 - val_accuracy: 0.5018 - val_loss: 1.2816
# pérdida de prueba: 1.2721
# precisión de la prueba: 0.5079
# Epoch 1/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 188ms/step - accuracy: 0.4865 - loss: 1.3543 - val_accuracy: 0.5014 - val_loss: 1.3714
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - accuracy: 0.4956 - loss: 1.3257 - val_accuracy: 0.5117 - val_loss: 1.2615
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - accuracy: 0.4836 - loss: 1.3184 - val_accuracy: 0.5116 - val_loss: 1.2398
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 189ms/step - accuracy: 0.4877 - loss: 1.3054 - val_accuracy: 0.4912 - val_loss: 1.3082
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.4946 - loss: 1.2690 - val_accuracy: 0.5096 - val_loss: 1.2108
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.4961 - loss: 1.2458 - val_accuracy: 0.5097 - val_loss: 1.2405
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - accuracy: 0.5062 - loss: 1.2478 - val_accuracy: 0.5085 - val_loss: 1.1886
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 189ms/step - accuracy: 0.4936 - loss: 1.2286 - val_accuracy: 0.5035 - val_loss: 1.2333
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.5066 - loss: 1.2093 - val_accuracy: 0.5111 - val_loss: 1.1822
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 188ms/step - accuracy: 0.5128 - loss: 1.1979 - val_accuracy: 0.5108 - val_loss: 1.1714
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - accuracy: 0.4990 - loss: 1.2226 - val_accuracy: 0.5094 - val_loss: 1.1759
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 191ms/step - accuracy: 0.4949 - loss: 1.2030 - val_accuracy: 0.5116 - val_loss: 1.1729
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - accuracy: 0.4973 - loss: 1.1894 - val_accuracy: 0.5082 - val_loss: 1.1550
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - accuracy: 0.5123 - loss: 1.1731 - val_accuracy: 0.5098 - val_loss: 1.1568
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.5001 - loss: 1.1914 - val_accuracy: 0.5118 - val_loss: 1.1444
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 191ms/step - accuracy: 0.5126 - loss: 1.1688 - val_accuracy: 0.5130 - val_loss: 1.1438
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - accuracy: 0.4996 - loss: 1.1660 - val_accuracy: 0.5108 - val_loss: 1.1529
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.4976 - loss: 1.1702 - val_accuracy: 0.5085 - val_loss: 1.1449
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - accuracy: 0.5150 - loss: 1.1643 - val_accuracy: 0.5120 - val_loss: 1.1521

# %% [markdown]
# # Enfoque
#
# El modelo se basó en la clasificación de casos COVID-19. La estructura del modelo es una red LSTM bidimensional, con dos capas LSTM de 128 y 64 unidades. Dentro de este, mediante la moda, reemplacé valores vacíos con valores estimados. Omití columnas innecesarias y transformé las variables categóricas en representaciones numéricas mediante one-hot. Los datos de entrada los escalé con MinMaxScaler para dar estabilidad y eficiencia al entrenamiento. Incorporé Batch Normalization para estabilizar el modelo y Dropout para disminuir el sobreajuste. Y para la capa de salida usé softmax para la clasificación multiclase.
# Usé la función de perdida categorial_crossentropy y el optimizador Adam con una tasa de aprendizaje 0.0005. El modelo se entrena por 100 épocas con un tamaño de “lote” de 64 y por última se evalúa empleando precisión en el conjunto de prueba.
